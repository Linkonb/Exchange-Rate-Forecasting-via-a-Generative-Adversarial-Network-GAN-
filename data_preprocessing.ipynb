# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web
import datetime as dt

# %%
# !pip install --upgrade pandas-datareader

# %%
import pandas_datareader
pandas_datareader.__version__
# Out:
# '0.10.0'

# %% [markdown]
# Symbol	Name	Last Price	Change	% Change	52 Week Range	Day Chart
# EURUSD=X	EUR/USD	1.0831	-0.0011	-0.10%
# JPY=X	USD/JPY	151.9150	+0.3060	+0.20%
# GBPUSD=X	GBP/USD	1.2620	-0.0018	-0.14%
# AUDUSD=X	AUD/USD	0.6588	+0.0007	+0.11%
# NZDUSD=X	NZD/USD	0.6018	+0.0004	+0.06%
# EURJPY=X	EUR/JPY	164.4900	+0.1680	+0.10%
# GBPJPY=X	GBP/JPY	191.6910	+0.0790	+0.04%
# EURGBP=X	EUR/GBP	0.8581	+0.0005	+0.06%
# EURCAD=X	EUR/CAD	1.4714	-0.0010	-0.07%
# EURSEK=X	EUR/SEK	11.4645	-0.0651	-0.56%
# EURCHF=X	EUR/CHF	0.9813	+0.0040	+0.41%
# EURHUF=X	EUR/HUF	390.5700	+0.8400	+0.22%
# EURJPY=X	EUR/JPY	164.4900	+0.1680	+0.10%
# CNY=X	USD/CNY	7.2320	-0.0005	-0.01%
# HKD=X	USD/HKD	7.8314	+0.0033	+0.04%
# SGD=X	USD/SGD	1.3494	+0.0009	+0.07%
# INR=X	USD/INR	83.2730	0.0000	0.00%
# MXN=X	USD/MXN	16.4356	-0.0124	-0.08%
# PHP=X	USD/PHP	56.4700	-0.0300	-0.05%
# IDR=X	USD/IDR	15,840.0000	+1.0000	+0.01%
# THB=X	USD/THB	36.7500	+0.1900	+0.52%
# MYR=X	USD/MYR	4.7485	+0.0035	+0.07%
# ZAR=X	USD/ZAR	18.6186	-0.0480	-0.26%
# RUB=X	USD/RUB	92.6636	+0.1136	+0.12%

# %%
from pandas_datareader import data as pdr #import pandas datareader

import yfinance as yf # you will need to install it if haven't done it already

#override the data reader function

yf.pdr_override()

#data = web.DataReader('0050.TW', "yahoo", start, end)
#data = pdr.get_data_yahoo("TSLA", start="2022-12-01", end="2023-02-08") #
#data = web.DataReader('DEXINUS', 'fred', start, end) #DEXJPUS DEXUSUK DEXUSEU

'''
data = pdr.get_data_yahoo("JPY=X", start="2014-01-01", end="2023-12-31") #
data['EURUSD'] = pdr.get_data_yahoo("EURUSD=X", start="2014-01-01", end="2023-12-31")['Open'] - pdr.get_data_yahoo("EURUSD=X", start="2014-01-01", end="2023-12-31")['Close']
data['GBPUSD'] = pdr.get_data_yahoo("GBPUSD=X", start="2014-01-01", end="2023-12-31")['Open'] - pdr.get_data_yahoo("GBPUSD=X", start="2014-01-01", end="2023-12-31")['Close']
data['AUDUSD'] = pdr.get_data_yahoo("AUDUSD=X", start="2014-01-01", end="2023-12-31")['Open'] -pdr.get_data_yahoo("AUDUSD=X", start="2014-01-01", end="2023-12-31")['Close']
data['NZDUSD'] = pdr.get_data_yahoo("NZDUSD=X", start="2014-01-01", end="2023-12-31")['Open'] - pdr.get_data_yahoo("NZDUSD=X", start="2014-01-01", end="2023-12-31")['Close']
data['EURJPY'] =  pdr.get_data_yahoo("EURJPY=X", start="2014-01-01", end="2023-12-31")['Open'] -pdr.get_data_yahoo("EURJPY=X", start="2014-01-01", end="2023-12-31")['Close']
data['GBPJPY'] =  pdr.get_data_yahoo("GBPJPY=X", start="2014-01-01", end="2023-12-31")['Open'] -pdr.get_data_yahoo("GBPJPY=X", start="2014-01-01", end="2023-12-31")['Close']
data['EURJPY'] =  pdr.get_data_yahoo("EURJPY=X", start="2014-01-01", end="2023-12-31")['Open'] -pdr.get_data_yahoo("EURJPY=X", start="2014-01-01", end="2023-12-31")['Close']
data['CNY'] =  pdr.get_data_yahoo("CNY=X", start="2014-01-01", end="2023-12-31")['Open'] -pdr.get_data_yahoo("CNY=X", start="2014-01-01", end="2023-12-31")['Close']
data['HKD'] =  pdr.get_data_yahoo("HKD=X", start="2014-01-01", end="2023-12-31")['Open'] -pdr.get_data_yahoo("HKD=X", start="2014-01-01", end="2023-12-31")['Close']
data['SGD'] =  pdr.get_data_yahoo("SGD=X", start="2014-01-01", end="2023-12-31")['Open'] -pdr.get_data_yahoo("SGD=X", start="2014-01-01", end="2023-12-31")['Close']
data['INR'] =  pdr.get_data_yahoo("INR=X", start="2014-01-01", end="2023-12-31")['Open'] -pdr.get_data_yahoo("INR=X", start="2014-01-01", end="2023-12-31")['Close']
'''

data = pdr.get_data_yahoo("JPY=X", start="2014-01-01", end="2023-12-31")
data['EURUSD'] = pdr.get_data_yahoo("EURUSD=X", start="2014-01-01", end="2023-12-31")['Close']
data['GBPUSD'] = pdr.get_data_yahoo("GBPUSD=X", start="2014-01-01", end="2023-12-31")['Close']
data['AUDUSD'] = pdr.get_data_yahoo("AUDUSD=X", start="2014-01-01", end="2023-12-31")['Close']
data['NZDUSD'] = pdr.get_data_yahoo("NZDUSD=X", start="2014-01-01", end="2023-12-31")['Close']
data['EURJPY'] =  pdr.get_data_yahoo("EURJPY=X", start="2014-01-01", end="2023-12-31")['Close']
data['GBPJPY'] =  pdr.get_data_yahoo("GBPJPY=X", start="2014-01-01", end="2023-12-31")['Close']
data['EURJPY'] =  pdr.get_data_yahoo("EURJPY=X", start="2014-01-01", end="2023-12-31")['Close']
data['CNY'] =  pdr.get_data_yahoo("CNY=X", start="2014-01-01", end="2023-12-31")['Close']
data['HKD'] =  pdr.get_data_yahoo("HKD=X", start="2014-01-01", end="2023-12-31")['Close']
data['SGD'] =  pdr.get_data_yahoo("SGD=X", start="2014-01-01", end="2023-12-31")['Close']
data['INR'] =  pdr.get_data_yahoo("INR=X", start="2014-01-01", end="2023-12-31")['Close']
# Out:
# yfinance: pandas_datareader support is deprecated & semi-broken so will be removed in a future verison. Just use yfinance.
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
#data.info()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-01  105.300003  105.300003  105.260002  105.300003  105.300003
# 2014-01-02  105.317001  105.430000  104.714996  105.323997  105.323997
# 2014-01-03  104.823997  104.858002  104.071999  104.833000  104.833000
# 2014-01-06  104.900002  104.925003  104.160004  104.912003  104.912003
# 2014-01-07  104.221001  104.711998  104.202003  104.209999  104.209999
#
#             Volume    EURUSD    GBPUSD    AUDUSD    NZDUSD      EURJPY  \
# Date
# 2014-01-01       0  1.374495  1.656397  0.891504  0.822707  144.750000
# 2014-01-02       0  1.376671  1.658072  0.889205  0.820883  145.011002
# 2014-01-03       0  1.366662  1.644791  0.890631  0.818733  143.257004
# 2014-01-06       0  1.359601  1.641309  0.896539  0.826720  142.626007
# 2014-01-07       0  1.363196  1.641794  0.896700  0.828981  142.044998
#
#                 GBPJPY     CNY      HKD      SGD        INR
# Date
# ...

# %%
data['pct_change'] = (data['Close'] - data['Close'].shift(1))/ data['Close'].shift(1)
data['log_change'] = np.log(data['Close']/ data['Close'].shift(1))


data['bull_bear'] = data['Close'] - data['Open']

data.loc[data.bull_bear > 0, 'bull_bear'] = 1
data.loc[data.bull_bear < 0, 'bull_bear'] = 0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# Append the directory to your python path using sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/Currency Exchange Rate Prediction/tools/')
# Import the module
import technical_generator

# %%
Generator = technical_generator.Generator()

# %%
data['7ma'] = Generator.EMA(data['Close'], 7)
data['14ma'] = Generator.EMA(data['Close'], 14)
data['21ma'] = Generator.EMA(data['Close'], 21)
data['7macd'] = Generator.MACD(data['Close'], 3, 11, 7)
data['14macd'] = Generator.MACD(data['Close'], 7, 21, 14)
data['7rsi'] = Generator.RSI(data['Close'], 7)
data['14rsi'] = Generator.RSI(data['Close'], 14)
data['21rsi'] = Generator.RSI(data['Close'], 21)
data['7atr'] = Generator.atr(data['High'], data['Low'], 7)
data['14atr'] = Generator.atr(data['High'], data['Low'], 14)
data['21atr'] = Generator.atr(data['High'], data['Low'], 21)
data['7upper'], data['7lower'] = Generator.bollinger_band(data['Close'], 7)
data['14upper'], data['14lower'] = Generator.bollinger_band(data['Close'], 14)
data['21upper'], data['21lower'] = Generator.bollinger_band(data['Close'], 21)
data['7rsv'] = Generator.rsv(data['Close'], 7)
data['14rsv'] = Generator.rsv(data['Close'], 14)
data['21rsv'] = Generator.rsv(data['Close'], 21)

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-01  105.300003  105.300003  105.260002  105.300003  105.300003
# 2014-01-02  105.317001  105.430000  104.714996  105.323997  105.323997
# 2014-01-03  104.823997  104.858002  104.071999  104.833000  104.833000
# 2014-01-06  104.900002  104.925003  104.160004  104.912003  104.912003
# 2014-01-07  104.221001  104.711998  104.202003  104.209999  104.209999
#
#             Volume    EURUSD    GBPUSD    AUDUSD    NZDUSD  ...  21atr  \
# Date                                                        ...
# 2014-01-01       0  1.374495  1.656397  0.891504  0.822707  ...    NaN
# 2014-01-02       0  1.376671  1.658072  0.889205  0.820883  ...    NaN
# 2014-01-03       0  1.366662  1.644791  0.890631  0.818733  ...    NaN
# 2014-01-06       0  1.359601  1.641309  0.896539  0.826720  ...    NaN
# 2014-01-07       0  1.363196  1.641794  0.896700  0.828981  ...    NaN
#
# ...

# %%
#other_data = pd.read_csv('./assets/other_data.csv', index_col = 'Date', parse_dates = True)
#other_data.head()

# %%
#other_data.index

# %%
#data_combine = data.merge(other_data, how = 'left', left_index = True, right_index = True)
#data_combine

# %%
data_combine=data

# %%
data_combine = data_combine.dropna()
data_combine.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-30  102.239998  102.779999  102.087997  102.300003  102.300003
# 2014-01-31  102.727997  102.907997  102.014999  102.758003  102.758003
# 2014-02-03  102.237999  102.393997  101.255997  102.192001  102.192001
# 2014-02-04  101.156998  101.567001  100.783997  101.141998  101.141998
# 2014-02-05  101.669998  101.671997  100.820999  101.689003  101.689003
#
#             Volume    EURUSD    GBPUSD    AUDUSD    NZDUSD  ...     21atr  \
# Date                                                        ...
# 2014-01-30       0  1.365859  1.655903  0.874891  0.821490  ...  0.757239
# 2014-01-31       0  1.355877  1.649838  0.879585  0.817595  ...  0.765715
# 2014-02-03       0  1.348818  1.643791  0.875657  0.810504  ...  0.782477
# 2014-02-04       0  1.352503  1.630896  0.875044  0.807103  ...  0.783334
# 2014-02-05       0  1.351589  1.633053  0.891425  0.822504  ...  0.799572
#
# ...

# %%
x_ = np.arange(data_combine.shape[0])
plt.figure(figsize=(12, 6))
plt.plot(data_combine['7ma'].values, label = 'MA 7', color = 'g', linestyle = '--')
plt.plot(data_combine['Close'].values, label = 'Closing price', color = 'b')
plt.plot(data_combine['21ma'].values, label = 'MA 21', color = 'r', linestyle = '--')
plt.plot(data_combine['7upper'].values, label = 'Upper Bound', color = 'c')
plt.plot(data_combine['7lower'].values, label = 'Lower Bound', color = 'c')
plt.fill_between(x_, data_combine['7lower'].values, data_combine['7upper'].values, alpha = 0.35)
plt.title('Technical indicators')
plt.ylabel('JPY=X')
plt.xlabel('Days')
plt.legend()

# %%
close_fft = np.fft.fft(np.asarray(data_combine['Close'].tolist()))
fft_df = pd.DataFrame({'fft':close_fft})
fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))

plt.figure(figsize=(14, 7), dpi=100)
fft_list = np.asarray(fft_df['fft'].tolist())
for num_ in [3, 6, 9, 27, 81, 100]:
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_] = 0
    data_combine[f'FT_{num_}components'] = np.fft.ifft(fft_list_m10)
    plt.plot(np.fft.ifft(fft_list_m10), label='Fourier transform with {} components'.format(num_))
plt.plot(data_combine['Close'].values,  label='Real')
plt.xlabel('Days')
plt.ylabel('JPY=X')
plt.title('TSMC (close) stock prices & Fourier transforms')
plt.legend()
plt.show()
# Out:
# <ipython-input-40-9f260e6592c9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_combine[f'FT_{num_}components'] = np.fft.ifft(fft_list_m10)
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# <ipython-input-40-9f260e6592c9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_combine[f'FT_{num_}components'] = np.fft.ifft(fft_list_m10)
# ...

# %%
data_combine['FT_3components'] = data_combine['FT_3components'].astype('float')
data_combine['FT_6components'] = data_combine['FT_6components'].astype('float')
data_combine['FT_9components'] = data_combine['FT_9components'].astype('float')
data_combine['FT_27components'] = data_combine['FT_27components'].astype('float')
data_combine['FT_81components'] = data_combine['FT_81components'].astype('float')
data_combine['FT_100components'] = data_combine['FT_100components'].astype('float')
data_combine.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py:138: ComplexWarning: Casting complex values to real discards the imaginary part
#   return arr.astype(dtype, copy=True)
# <ipython-input-41-4c509cee5b72>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_combine['FT_3components'] = data_combine['FT_3components'].astype('float')
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py:138: ComplexWarning: Casting complex values to real discards the imaginary part
#   return arr.astype(dtype, copy=True)
# <ipython-input-41-4c509cee5b72>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_combine.to_csv('/content/drive/MyDrive/Colab Notebooks/Currency Exchange Rate Prediction/assets/data.csv')

# %%
data_combine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2583 entries, 2014-01-30 to 2023-12-29
# Data columns (total 45 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              2583 non-null   float64
#  1   High              2583 non-null   float64
#  2   Low               2583 non-null   float64
#  3   Close             2583 non-null   float64
#  4   Adj Close         2583 non-null   float64
#  5   Volume            2583 non-null   int64
#  6   EURUSD            2583 non-null   float64
#  7   GBPUSD            2583 non-null   float64
#  8   AUDUSD            2583 non-null   float64
#  9   NZDUSD            2583 non-null   float64
#  10  EURJPY            2583 non-null   float64
#  11  GBPJPY            2583 non-null   float64
#  12  CNY               2583 non-null   float64
#  13  HKD               2583 non-null   float64
#  14  SGD               2583 non-null   float64
# ...
